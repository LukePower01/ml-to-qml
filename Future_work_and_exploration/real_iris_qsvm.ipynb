# %%
import time
start_time = time.time()
from qiskit_ibm_provider import IBMProvider
provider = IBMProvider()

# %%
import time
import numpy as np
import pandas as pd
from sklearn.datasets import load_iris
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler, MinMaxScaler
from sklearn.exceptions import ConvergenceWarning
from qiskit import QuantumCircuit, transpile
from qiskit.circuit.library import ZZFeatureMap
from qiskit_machine_learning.circuit.library import QNNCircuit
from qiskit_machine_learning.algorithms import QSVC
from qiskit_machine_learning.kernels import FidelityQuantumKernel
from qiskit_machine_learning.neural_networks import SamplerQNN, EstimatorQNN
from qiskit.primitives import Sampler,BackendSampler
from qiskit_algorithms.optimizers import COBYLA, L_BFGS_B, ADAM, SLSQP, AQGD
from qiskit_algorithms.utils import algorithm_globals
from qiskit.visualization import plot_histogram
from qiskit_ibm_provider import IBMProvider
from qiskit_algorithms.state_fidelities import ComputeUncompute

# %%
# Set the seed for reproducibility
algorithm_globals.random_seed = 4701

# Load and preprocess the Iris dataset
iris_data = load_iris()
features = MinMaxScaler().fit_transform(iris_data.data)
labels = iris_data.target

# Split the dataset into training and test sets
train_features, test_features, train_labels, test_labels = train_test_split(
    features, labels, train_size=0.8, random_state=algorithm_globals.random_seed)


num_features = features.shape[1]
iris_feature_map = ZZFeatureMap(feature_dimension=num_features, reps=2, entanglement="linear")


provider = IBMProvider()
backend = provider.get_backend('ibm_osaka') 


sampler = BackendSampler(backend=backend)
fidelity = ComputeUncompute(sampler=sampler)
iris_kernel = FidelityQuantumKernel(fidelity=fidelity, feature_map=iris_feature_map)

# %%
qsvc.fit(train_features, train_labels)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[2], line 1
# ----> 1 qsvc = QSVC(quantum_kernel=iris_kernel, probability=True)
#       2 qsvc.fit(train_features, train_labels)
#
# NameError: name 'QSVC' is not defined

# %%
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[14], line 1
# ----> 1 qsvc = QSVC(quantum_kernel=iris_kernel, probability=True)
#
# NameError: name 'iris_kernel' is not defined

# %%
qsvc.score(test_features, test_labels)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[13], line 1
# ----> 1 qsvc.score(test_features, test_labels)
#
# NameError: name 'qsvc' is not defined

# %%
print(f"Total time elapsed: {end_time - start_time} seconds")
qsvc_full.save('quantum_classifiers/real_iris_qsvc.model')

# %%
import qiskit as qiskit
qiskit.utils.local_hardware_info()
# Out:
# {'python_compiler': 'Clang 16.0.6 ',
#  'python_build': 'main, Dec 23 2023 08:05:03',
#  'python_version': '3.12.1',
#  'os': 'Darwin',
#  'cpus': 4}

# %%
job = provider.retrieve_job('crehssfwverg008vsqe0')

# %%
job_result = job.result()

# %%
job_result
# Out:
# Result(backend_name='ibm_osaka', backend_version='0.0.0', qobj_id='Unknown', job_id='Unknown', success=True, results=[ExperimentResult(shots=4000, success=True, meas_level=2, data=ExperimentResultData(counts={'0x9': 378, '0x8': 632, '0x5': 173, '0xa': 129, '0xe': 299, '0x6': 289, '0xb': 116, '0x0': 454, '0x3': 222, '0x7': 429, '0xd': 249, '0xf': 140, '0x2': 108, '0x1': 171, '0xc': 102, '0x4': 109}), header=QobjExperimentHeader(qubit_labels=[['q', 0], ['q', 1], ['q', 2], ['q', 3], ['q', 4], ['q', 5], ['q', 6], ['q', 7], ['q', 8], ['q', 9], ['q', 10], ['q', 11], ['q', 12], ['q', 13], ['q', 14], ['q', 15], ['q', 16], ['q', 17], ['q', 18], ['q', 19], ['q', 20], ['q', 21], ['q', 22], ['q', 23], ['q', 24], ['q', 25], ['q', 26], ['q', 27], ['q', 28], ['q', 29], ['q', 30], ['q', 31], ['q', 32], ['q', 33], ['q', 34], ['q', 35], ['q', 36], ['q', 37], ['q', 38], ['q', 39], ['q', 40], ['q', 41], ['q', 42], ['q', 43], ['q', 44], ['q', 45], ['q', 46], ['q', 47], ['q', 48], ['q', 49], ['q', 50], ['q', 51], ['q', 52], ['q', 53], ['q', 54], ['q', 55], ['q', 56], ['q', 57], ['q', 58], ['q', 59], ['q', 60], ['q', 61], ['q', 62], ['q', 63], ['q', 64], ['q', 65], ['q', 66], ['q', 67], ['q', 68], ['q', 69], ['q', 70], ['