# %%
import time
start_time = time.time()
from qiskit_ibm_provider import IBMProvider
provider = IBMProvider()

# %%
import time
import numpy as np
import pandas as pd
from sklearn.datasets import load_iris
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler, MinMaxScaler
from sklearn.exceptions import ConvergenceWarning
from qiskit import QuantumCircuit, transpile
from qiskit.circuit.library import ZZFeatureMap
from qiskit_machine_learning.circuit.library import QNNCircuit
from qiskit_machine_learning.algorithms import QSVC
from qiskit_machine_learning.kernels import FidelityQuantumKernel
from qiskit_machine_learning.neural_networks import SamplerQNN, EstimatorQNN
from qiskit.primitives import Sampler,BackendSampler
from qiskit_algorithms.optimizers import COBYLA, L_BFGS_B, ADAM, SLSQP, AQGD
from qiskit_algorithms.utils import algorithm_globals
from qiskit.visualization import plot_histogram
from qiskit_ibm_provider import IBMProvider
from qiskit_algorithms.state_fidelities import ComputeUncompute

# %%
# Set the seed for reproducibility
algorithm_globals.random_seed = 4701

# Load and preprocess the Iris dataset
iris_data = load_iris()
features = MinMaxScaler().fit_transform(iris_data.data)
labels = iris_data.target

# Split the dataset into training and test sets
train_features, test_features, train_labels, test_labels = train_test_split(
    features, labels, train_size=0.8, random_state=algorithm_globals.random_seed)


num_features = features.shape[1]
iris_feature_map = ZZFeatureMap(feature_dimension=num_features, reps=2, entanglement="linear")


provider = IBMProvider()
backend = provider.get_backend('ibm_osaka') 


sampler = BackendSampler(backend=backend)
fidelity = ComputeUncompute(sampler=sampler)
iris_kernel = FidelityQuantumKernel(fidelity=fidelity, feature_map=iris_feature_map)

# %%
qsvc = QSVC(quantum_kernel=iris_kernel, probability=True)
qsvc.fit(train_features, train_labels)


print(f"Total time elapsed: {end_time - start_time} seconds")
qsvc_full.save('quantum_classifiers/real_iris_qsvc.model')
# Out:
# ---------------------------------------------------------------------------
# HTTPError                                 Traceback (most recent call last)
# File ~/Library/jupyterlab-desktop/jlab_server/lib/python3.12/site-packages/qiskit_ibm_provider/api/session.py:264, in RetrySession.request(self, method, url, bare, **kwargs)
#     263     response = super().request(method, final_url, headers=headers, **kwargs)
# --> 264     response.raise_for_status()
#     265 except RequestException as ex:
#     266     # Wrap the requests exceptions into a IBM Q custom one, for
#     267     # compatibility.
#
# File ~/Library/jupyterlab-desktop/jlab_server/lib/python3.12/site-packages/requests/models.py:1021, in Response.raise_for_status(self)
#    1020 if http_error_msg:
# -> 1021     raise HTTPError(http_error_msg, response=self)
#
# HTTPError: 409 Client Error: Conflict for url: https://api.quantum.ibm.com/runtime/jobs
#
# The above exception was the direct cause of the following exception:
#
# RequestsApiError                          Traceback (most recent call last)
# File ~/Library/jupyterlab-desktop/jlab_server/lib/python3.12/site-packages/qiskit_ibm_provider/ibm_backend.py:521, in IBMBackend._runtime_run(self, program_id, inputs, backend_name, job_tags, image)
#     520 try:
# --> 521     response = self.provider._runtime_client.program_run(
#     522         program_id=program_id,
#     523         backend_name=backend_name,
#     524         params=inputs,
#     525         hgp=hgp_name,
#     526         job_tags=job_tags,
#     527         session_id=session_id,
#     528         start_session=False,
#     529         image=image,
#     530     )
#     531 except RequestsApiError as ex:
#
# File ~/Library/jupyterlab-desktop/jlab_server/lib/python3.12/site-packages/qiskit_ibm_provider/api/clients/runtime.py:141, in RuntimeClient.program_run(self, program_id, backend_name, params, image, hgp, log_level, session_id, job_tags, max_execution_time, session_time, start_session)
#     140     hgp_dict = {"hub": hub, "group": group, "project": project}
# --> 141 return self._api.program_run(
#     142     program_id=program_id,
#     143     backend_name=backend_name,
#     144     params=params,
#     145     image=image,
#     146     log_level=log_level,
#     147     session_id=session_id,
#     148     job_tags=job_tags,
#     149     max_execution_time=max_execution_time,
#     150     start_session=start_session,
#     151     session_time=session_time,
#     152     **hgp_dict
#     153 )
#
# File ~/Library/jupyterlab-desktop/jlab_server/lib/python3.12/site-packages/qiskit_ibm_provider/api/rest/runtime.py:134, in Runtime.program_run(self, program_id, backend_name, params, image, hub, group, project, log_level, session_id, job_tags, max_execution_time, session_time, start_session)
#     133 data = json.dumps(payload, cls=RuntimeEncoder)
# --> 134 return self.session.post(url, data=data, timeout=900).json()
#
# File ~/Library/jupyterlab-desktop/jlab_server/lib/python3.12/site-packages/requests/sessions.py:637, in Session.post(self, url, data, json, **kwargs)
#     627 r"""Sends a POST request. Returns :class:`Response` object.
#     628
#     629 :param url: URL for the new :class:`Request` object.
#    (...)
#     634 :rtype: requests.Response
#     635 """
# --> 637 return self.request("POST", url, data=data, json=json, **kwargs)
#
# File ~/Library/jupyterlab-desktop/jlab_server/lib/python3.12/site-packages/qiskit_ibm_provider/api/session.py:285, in RetrySession.request(self, method, url, bare, **kwargs)
#     283             message += f". {ex.response.text}"
# --> 285     raise RequestsApiError(message, status_code) from ex
#     287 return response
#
# RequestsApiError: '409 Client Error: Conflict for url: https://api.quantum.ibm.com/runtime/jobs. {"errors":[{"message":"You have reached the limit of 3 pending  jobs. Please wait for a job to complete or cancel one before submitting anything new.","code":3458,"solution":"Wait until some previous jobs were finished. You can cancel pending jobs to run new jobs.","more_info":"https://docs.quantum-computing.ibm.com/errors"}]}'
#
# The above exception was the direct cause of the following exception:
#
# IBMBackendApiError                        Traceback (most recent call last)
# File ~/Library/jupyterlab-desktop/jlab_server/lib/python3.12/site-packages/qiskit_algorithms/state_fidelities/compute_uncompute.py:170, in ComputeUncompute._call(job, circuits, local, local_opts)
#     169 try:
# --> 170     result = job.result()
#     171 except Exception as exc:
#
# File ~/Library/jupyterlab-desktop/jlab_server/lib/python3.12/site-packages/qiskit/primitives/primitive_job.py:51, in PrimitiveJob.result(self)
#      50 self._check_submitted()
# ---> 51 return self._future.result()
#
# File ~/Library/jupyterlab-desktop/jlab_server/lib/python3.12/concurrent/futures/_base.py:456, in Future.result(self, timeout)
#     455 elif self._state == FINISHED:
# --> 456     return self.__get_result()
#     457 else:
#
# File ~/Library/jupyterlab-desktop/jlab_server/lib/python3.12/concurrent/futures/_base.py:401, in Future.__get_result(self)
#     400 try:
# --> 401     raise self._exception
#     402 finally:
#     403     # Break a reference cycle with the exception in self._exception
#
# File ~/Library/jupyterlab-desktop/jlab_server/lib/python3.12/concurrent/futures/thread.py:58, in _WorkItem.run(self)
#      57 try:
# ---> 58     result = self.fn(*self.args, **self.kwargs)
#      59 except BaseException as exc:
#
# File ~/Library/jupyterlab-desktop/jlab_server/lib/python3.12/site-packages/qiskit/primitives/backend_sampler.py:153, in BackendSampler._call(self, circuits, parameter_values, **run_options)
#     152 # Run
# --> 153 result, _metadata = _run_circuits(bound_circuits, self._backend, **run_options)
#     154 return self._postprocessing(result, bound_circuits)
#
# File ~/Library/jupyterlab-desktop/jlab_server/lib/python3.12/site-packages/qiskit/primitives/backend_estimator.py:70, in _run_circuits(circuits, backend, **run_options)
#      68 if max_circuits:
#      69     jobs = [
# ---> 70         backend.run(circuits[pos : pos + max_circuits], **run_options)
#      71         for pos in range(0, len(circuits), max_circuits)
#      72     ]
#      73     result = [x.result() for x in jobs]
#
# File ~/Library/jupyterlab-desktop/jlab_server/lib/python3.12/site-packages/qiskit_ibm_provider/ibm_backend.py:495, in IBMBackend.run(self, circuits, dynamic, job_tags, init_circuit, init_num_resets, header, shots, memory, meas_level, meas_return, rep_delay, init_qubits, use_measure_esp, noise_model, seed_simulator, **run_config)
#     493     run_config_dict["skip_transpilation"] = True
# --> 495 return self._runtime_run(
#     496     program_id=program_id,
#     497     inputs=run_config_dict,
#     498     backend_name=self.name,
#     499     job_tags=job_tags,
#     500     image=image,
#     501 )
#
# File ~/Library/jupyterlab-desktop/jlab_server/lib/python3.12/site-packages/qiskit_ibm_provider/ibm_backend.py:532, in IBMBackend._runtime_run(self, program_id, inputs, backend_name, job_tags, image)
#     531 except RequestsApiError as ex:
# --> 532     raise IBMBackendApiError("Error submitting job: {}".format(str(ex))) from ex
#     533 try:
#
# IBMBackendApiError: 'Error submitting job: \'409 Client Error: Conflict for url: https://api.quantum.ibm.com/runtime/jobs. {"errors":[{"message":"You have reached the limit of 3 pending  jobs. Please wait for a job to complete or cancel one before submitting anything new.","code":3458,"solution":"Wait until some previous jobs were finished. You can cancel pending jobs to run new jobs.","more_info":"https://docs.quantum-computing.ibm.com/errors"}]}\''
#
# The above exception was the direct cause of the following exception:
#
# AlgorithmError                            Traceback (most recent call last)
# Cell In[23], line 3
#       1 # Set up and train the Quantum Support Vector Classifier
#       2 qsvc = QSVC(quantum_kernel=iris_kernel, probability=True)
# ----> 3 qsvc.fit(train_features, train_labels)
#       5 # Evaluate the classifier on the test set
#       6 qsvc_score = qsvc.score(test_features, test_labels)
#
# File ~/Library/jupyterlab-desktop/jlab_server/lib/python3.12/site-packages/sklearn/base.py:1474, in _fit_context.<locals>.decorator.<locals>.wrapper(estimator, *args, **kwargs)
#    1467     estimator._validate_params()
#    1469 with config_context(
#    1470     skip_parameter_validation=(
#    1471         prefer_skip_nested_validation or global_skip_validation
#    1472     )
#    1473 ):
# -> 1474     return fit_method(estimator, *args, **kwargs)
#
# File ~/Library/jupyterlab-desktop/jlab_server/lib/python3.12/site-packages/sklearn/svm/_base.py:250, in BaseLibSVM.fit(self, X, y, sample_weight)
#     247     print("[LibSVM]", end="")
#     249 seed = rnd.randint(np.iinfo("i").max)
# --> 250 fit(X, y, sample_weight, solver_type, kernel, random_seed=seed)
#     251 # see comment on the other call to np.iinfo in this file
#     253 self.shape_fit_ = X.shape if hasattr(X, "shape") else (n_samples,)
#
# File ~/Library/jupyterlab-desktop/jlab_server/lib/python3.12/site-packages/sklearn/svm/_base.py:310, in BaseLibSVM._dense_fit(self, X, y, sample_weight, solver_type, kernel, random_seed)
#     306 if callable(self.kernel):
#     307     # you must store a reference to X to compute the kernel in predict
#     308     # TODO: add keyword copy to copy on demand
#     309     self.__Xfit = X
# --> 310     X = self._compute_kernel(X)
#     312     if X.shape[0] != X.shape[1]:
#     313         raise ValueError("X.shape[0] should be equal to X.shape[1]")
#
# File ~/Library/jupyterlab-desktop/jlab_server/lib/python3.12/site-packages/sklearn/svm/_base.py:508, in BaseLibSVM._compute_kernel(self, X)
#     504 """Return the data transformed by a callable kernel"""
#     505 if callable(self.kernel):
#     506     # in the case of precomputed kernel given as a function, we
#     507     # have to compute explicitly the kernel matrix
# --> 508     kernel = self.kernel(X, self.__Xfit)
#     509     if sp.issparse(kernel):
#     510         kernel = kernel.toarray()
#
# File ~/Library/jupyterlab-desktop/jlab_server/lib/python3.12/site-packages/qiskit_machine_learning/kernels/fidelity_quantum_kernel.py:106, in FidelityQuantumKernel.evaluate(self, x_vec, y_vec)
#     104 if is_symmetric:
#     105     left_parameters, right_parameters, indices = self._get_symmetric_parameterization(x_vec)
# --> 106     kernel_matrix = self._get_symmetric_kernel_matrix(
#     107         kernel_shape, left_parameters, right_parameters, indices
#     108     )
#     109 else:
#     110     left_parameters, right_parameters, indices = self._get_parameterization(x_vec, y_vec)
#
# File ~/Library/jupyterlab-desktop/jlab_server/lib/python3.12/site-packages/qiskit_machine_learning/kernels/fidelity_quantum_kernel.py:194, in FidelityQuantumKernel._get_symmetric_kernel_matrix(self, kernel_shape, left_parameters, right_parameters, indices)
#     184 def _get_symmetric_kernel_matrix(
#     185     self,
#     186     kernel_shape: tuple[int, int],
#    (...)
#     189     indices: KernelIndices,
#     190 ) -> np.ndarray:
#     191     """
#     192     Given a set of parameterization, this computes the kernel matrix.
#     193     """
# --> 194     kernel_entries = self._get_kernel_entries(left_parameters, right_parameters)
#     195     kernel_matrix = np.ones(kernel_shape)
#     197     for i, (col, row) in enumerate(indices):
#
# File ~/Library/jupyterlab-desktop/jlab_server/lib/python3.12/site-packages/qiskit_machine_learning/kernels/fidelity_quantum_kernel.py:218, in FidelityQuantumKernel._get_kernel_entries(self, left_parameters, right_parameters)
#     211 if num_circuits != 0:
#     212     job = self._fidelity.run(
#     213         [self._feature_map] * num_circuits,
#     214         [self._feature_map] * num_circuits,
#     215         left_parameters,
#     216         right_parameters,
#     217     )
# --> 218     kernel_entries = job.result().fidelities
#     219 else:
#     220     # trivial case, only identical samples
#     221     kernel_entries = []
#
# File ~/Library/jupyterlab-desktop/jlab_server/lib/python3.12/site-packages/qiskit/primitives/primitive_job.py:51, in PrimitiveJob.result(self)
#      49 def result(self) -> ResultT:
#      50     self._check_submitted()
# ---> 51     return self._future.result()
#
# File ~/Library/jupyterlab-desktop/jlab_server/lib/python3.12/concurrent/futures/_base.py:456, in Future.result(self, timeout)
#     454     raise CancelledError()
#     455 elif self._state == FINISHED:
# --> 456     return self.__get_result()
#     457 else:
#     458     raise TimeoutError()
#
# File ~/Library/jupyterlab-desktop/jlab_server/lib/python3.12/concurrent/futures/_base.py:401, in Future.__get_result(self)
#     399 if self._exception:
#     400     try:
# --> 401         raise self._exception
#     402     finally:
#     403         # Break a reference cycle with the exception in self._exception
#     404         self = None
#
# File ~/Library/jupyterlab-desktop/jlab_server/lib/python3.12/concurrent/futures/thread.py:58, in _WorkItem.run(self)
#      55     return
#      57 try:
# ---> 58     result = self.fn(*self.args, **self.kwargs)
#      59 except BaseException as exc:
#      60     self.future.set_exception(exc)
#
# File ~/Library/jupyterlab-desktop/jlab_server/lib/python3.12/site-packages/qiskit_algorithms/state_fidelities/compute_uncompute.py:172, in ComputeUncompute._call(job, circuits, local, local_opts)
#     170     result = job.result()
#     171 except Exception as exc:
# --> 172     raise AlgorithmError("Sampler job failed!") from exc
#     174 if local:
#     175     raw_fidelities = [
#     176         ComputeUncompute._get_local_fidelity(prob_dist, circuit.num_qubits)
#     177         for prob_dist, circuit in zip(result.quasi_dists, circuits)
#     178     ]
#
# AlgorithmError: 'Sampler job failed!'

# %%
import qiskit as qiskit
qiskit.utils.local_hardware_info()
# Out:
# {'python_compiler': 'Clang 16.0.6 ',
#  'python_build': 'main, Dec 23 2023 08:05:03',
#  'python_version': '3.12.1',
#  'os': 'Darwin',
#  'cpus': 4}
